# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('breast_cancer_survival.csv') #upload dataset
df = df.reset_index()
df = df.rename(columns={'index':'Patient_ID'}) #create a patient ID column to use as key for the remaining steps 
df.sample(5)
# Out:
#      Patient_ID  Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 209         209   62  FEMALE   0.27503  0.881200 -0.513710 -0.023585
# 150         150   45  FEMALE  -0.27807  1.429100 -0.578950  0.222640
# 29           29   62  FEMALE   0.45690  0.739440 -0.631770 -0.060096
# 202         202   71  FEMALE   0.39409  1.705400  0.035642  1.441000
# 41           41   75  FEMALE   0.17164  0.029656 -0.158900  0.674710
#
#     Tumour_Stage                       Histology ER status PR status  \
# 209          III   Infiltrating Ductal Carcinoma  Positive  Positive
# 150           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 29            II  Infiltrating Lobular Carcinoma  Positive  Positive
# 202           II  Infiltrating Lobular Carcinoma  Positive  Positive
# 41             I  Infiltrating Lobular Carcinoma  Positive  Positive
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 209    Negative  Modified Radical Mastectomy       24-Jun-19
# 150    Negative  Modified Radical Mastectomy       06-Mar-19
# 29     Negative  Modified Radical Mastectomy       20-Feb-19
# 202    Negative  Modified Radical Mastectomy       26-Nov-18
# 41     Negative            Simple Mastectomy       24-Feb-17
#
#     Date_of_Last_Visit Patient_Status
# 209          15-Jan-20          Alive
# 150          10-Sep-20           Dead
# 29           18-Apr-19          Alive
# 202                NaN            NaN
# 41           05-Apr-17          Alive

# %%
#1. Melt
df_melt = df.melt(id_vars = ['Patient_ID'], value_vars= ['ER status', 'PR status', 'HER2 status'], var_name = 'Marker', value_name = 'Marker Status') #split out to just patients and markers using melt and rename columns to make this understandble
df_melt #this isn't super useful by itself but might help make a graph easier to create
# Out:
#       Patient_ID       Marker Marker Status
# 0              0    ER status      Positive
# 1              1    ER status      Positive
# 2              2    ER status      Positive
# 3              3    ER status      Positive
# 4              4    ER status      Positive
# ...          ...          ...           ...
# 997          329  HER2 status      Positive
# 998          330  HER2 status      Positive
# 999          331  HER2 status      Negative
# 1000         332  HER2 status      Negative
# 1001         333  HER2 status      Negative
#
# [1002 rows x 3 columns]

# %%
#2. Pivot
#hopefully it is okay to use pivot_table because there isn't a great reason to us pivot with this dataframe as there is no longitudinal data
df_pivot = pd.pivot_table(df, values = "Patient_ID", index = 'Histology', columns = 'Tumour_Stage', aggfunc = 'count', fill_value = 0) #this now shows the count of patients by tumour stage at dx and histology 
df_pivot
# Out:
# Tumour_Stage                     I   II  III
# Histology
# Infiltrating Ductal Carcinoma   50  124   59
# Infiltrating Lobular Carcinoma  11   56   22
# Mucinous Carcinoma               3    9    0

# %%
#3. Aggregation
df_agg = df[['Protein1', 'Protein2', 'Protein3', 'Protein4']] #limit to just the columns we want to use
df_agg = df_agg.agg(['min', 'max', 'mean']) #aggregate minimum, maximum, and mean of each protein expression across the whole dataset
df_agg
# Out:
#       Protein1  Protein2  Protein3  Protein4
# min  -2.340900 -0.978730 -1.627400 -2.025500
# max   1.593600  3.402200  2.193400  1.629900
# mean -0.029991  0.946896 -0.090204  0.009819

# %%
#4. Iterate
for x in df.__iter__(): #iterate over all the column names 
    print(x) #print all the column names 

df
# Out:
# Patient_ID
# Age
# Gender
# Protein1
# Protein2
# Protein3
# Protein4
# Tumour_Stage
# Histology
# ER status
# PR status
# HER2 status
# Surgery_type
# Date_of_Surgery
# Date_of_Last_Visit
# Patient_Status
#      Patient_ID  Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0             0   42  FEMALE  0.952560   2.15000  0.007972 -0.048340
# 1             1   54  FEMALE  0.000000   1.38020 -0.498030 -0.507320
# 2             2   63  FEMALE -0.523030   1.76400 -0.370190  0.010815
# 3             3   78  FEMALE -0.876180   0.12943 -0.370380  0.132190
# 4             4   42  FEMALE  0.226110   1.74910 -0.543970 -0.390210
# ..          ...  ...     ...       ...       ...       ...       ...
# 329         329   59  FEMALE  0.024598   1.40050  0.024751  0.280320
# 330         330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870
# 331         331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860
# 332         332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820
# 333         333   66  FEMALE  0.286380   1.39980  0.318830  0.836050
#
#     Tumour_Stage                       Histology ER status PR status  \
# 0             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 1             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 2             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 3              I   Infiltrating Ductal Carcinoma  Positive  Positive
# 4             II   Infiltrating Ductal Carcinoma  Positive  Positive
# ..           ...                             ...       ...       ...
# 329           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 330            I   Infiltrating Ductal Carcinoma  Positive  Positive
# 331           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 332           II  Infiltrating Lobular Carcinoma  Positive  Positive
# 333           II   Infiltrating Ductal Carcinoma  Positive  Positive
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative                        Other       20-May-18
# 1      Negative                        Other       26-Apr-18
# 2      Negative                   Lumpectomy       24-Aug-18
# 3      Negative                        Other       16-Nov-18
# 4      Positive                   Lumpectomy       12-Dec-18
# ..          ...                          ...             ...
# 329    Positive                   Lumpectomy       15-Jan-19
# 330    Positive  Modified Radical Mastectomy       25-Jul-18
# 331    Negative            Simple Mastectomy       26-Mar-19
# 332    Negative                   Lumpectomy       26-Nov-18
# 333    Negative  Modified Radical Mastectomy       04-Feb-19
#
#     Date_of_Last_Visit Patient_Status
# 0            26-Aug-18          Alive
# 1            25-Jan-19           Dead
# 2            08-Apr-20          Alive
# 3            28-Jul-20          Alive
# 4            05-Jan-19          Alive
# ..                 ...            ...
# 329          27-Mar-20          Alive
# 330          23-Apr-19          Alive
# 331          11-Oct-19           Dead
# 332          05-Dec-18          Alive
# 333          10-Aug-19           Dead
#
# [334 rows x 16 columns]

# %%
#4. Iterrows, in case we meant that instead of df.__iter__(), which does not do so m
for index, row in df.iterrows(): #iterrate over each row in the dataframe 
    print(f"Patient {row['Patient_ID']} had a {row['Surgery_type']} on {row['Date_of_Surgery']}") #print out a list of all the cases and the surgeries they had on which date
df
# Out:
# Patient 0 had a Other on 20-May-18
# Patient 1 had a Other on 26-Apr-18
# Patient 2 had a Lumpectomy on 24-Aug-18
# Patient 3 had a Other on 16-Nov-18
# Patient 4 had a Lumpectomy on 12-Dec-18
# Patient 5 had a Modified Radical Mastectomy on 25-Jun-18
# Patient 6 had a Lumpectomy on 27-Oct-18
# Patient 7 had a Modified Radical Mastectomy on 19-Jul-18
# Patient 8 had a Other on 15-Jun-18
# Patient 9 had a Other on 20-Jun-19
# Patient 10 had a Modified Radical Mastectomy on 26-Nov-18
# Patient 11 had a Other on 14-Feb-17
# Patient 12 had a Other on 27-Mar-18
# Patient 13 had a Modified Radical Mastectomy on 08-Aug-18
# Patient 14 had a Modified Radical Mastectomy on 09-Jun-18
# Patient 15 had a Lumpectomy on 16-May-18
# Patient 16 had a Other on 10-May-18
# Patient 17 had a Modified Radical Mastectomy on 15-May-19
# Patient 18 had a Other on 10-Jun-19
# Patient 19 had a Other on 15-Feb-18
# Patient 20 had a Simple Mastectomy on 15-Jul-18
# Patient 21 had a Modified Radical Mastectomy on 14-Feb-19
# Patient 22 had a Simple Mastectomy on 21-Jan-19
# Patient 23 had a Other on 05-Feb-18
# Patient 24 had a Simple Mastectomy on 29-Jul-18
# Patient 25 had a Lumpectomy on 27-Mar-18
# Patient 26 had a Other on 05-May-19
# Patient 27 had a Lumpectomy on 14-Feb-19
# Patient 28 had a Modified Radical Mastectomy on 11-Jan-19
# Patient 29 had a Modified Radical Mastectomy on 20-Feb-19
# Patient 30 had a Modified Radical Mastectomy on 04-Jun-19
# Patient 31 had a Modified Radical Mastectomy on 01-Mar-18
# Patient 32 had a Lumpectomy on 27-Nov-17
# Patient 33 had a Lumpectomy on 21-Mar-18
# Patient 34 had a Lumpectomy on 11-Nov-19
# Patient 35 had a Simple Mastectomy on 24-Jul-17
# Patient 36 had a Modified Radical Mastectomy on 28-Aug-18
# Patient 37 had a Other on 13-Sep-18
# Patient 38 had a Other on 18-Aug-18
# Patient 39 had a Simple Mastectomy on 11-Nov-17
# Patient 40 had a Other on 27-Dec-17
# Patient 41 had a Simple Mastectomy on 24-Feb-17
# Patient 42 had a Simple Mastectomy on 02-Sep-19
# Patient 43 had a Lumpectomy on 04-Jul-19
# Patient 44 had a Other on 24-Feb-19
# Patient 45 had a Modified Radical Mastectomy on 05-Jul-18
# Patient 46 had a Modified Radical Mastectomy on 04-Jul-19
# Patient 47 had a Other on 25-Jan-19
# Patient 48 had a Simple Mastectomy on 30-May-18
# Patient 49 had a Lumpectomy on 12-Oct-17
# Patient 50 had a Other on 24-Jun-17
# Patient 51 had a Simple Mastectomy on 27-Oct-18
# Patient 52 had a Simple Mastectomy on 19-Feb-18
# Patient 224 had a Other on 30-Apr-18
# Patient 225 had a Modified Radical Mastectomy on 03-Oct-18
# Patient 226 had a Other on 17-Oct-18
# Patient 227 had a Simple Mastectomy on 21-Dec-17
# Patient 228 had a Other on 30-May-18
# Patient 229 had a Simple Mastectomy on 04-Jun-19
# Patient 230 had a Other on 11-Dec-17
# Patient 231 had a Other on 16-Nov-18
# Patient 232 had a Lumpectomy on 25-Feb-18
# Patient 233 had a Lumpectomy on 14-Jul-19
# Patient 234 had a Other on 01-Apr-19
# Patient 235 had a Other on 24-Aug-18
# Patient 236 had a Other on 05-Jan-19
# Patient 237 had a Other on 07-Oct-18
# Patient 238 had a Simple Mastectomy on 17-Dec-17
# Patient 239 had a Modified Radical Mastectomy on 02-Dec-18
# Patient 240 had a Modified Radical Mastectomy on 15-Jan-19
# Patient 241 had a Simple Mastectomy on 17-Mar-18
# Patient 242 had a Simple Mastectomy on 24-Jul-19
# Patient 243 had a Modified Radical Mastectomy on 15-Jul-18
# Patient 244 had a Simple Mastectomy on 26-Mar-19
# Patient 245 had a Modified Radical Mastectomy on 01-Jan-19
# Patient 246 had a Other on 18-Aug-18
# Patient 247 had a Lumpectomy on 05-Jan-19
# Patient 248 had a Modified Radical Mastectomy on 05-Apr-19
# Patient 249 had a Other on 14-Jul-19
# Patient 250 had a Modified Radical Mastectomy on 20-Apr-18
# Patient 251 had a Modified Radical Mastectomy on 11-Mar-18
# Patient 252 had a Other on 08-Oct-17
# Patient 253 had a Other on 26-Mar-17
# Patient 254 had a Modified Radical Mastectomy on 23-Sep-18
# Patient 255 had a Other on 03-Aug-19
# Patient 256 had a Other on 05-Jun-18
# Patient 257 had a Other on 06-May-18
# Patient 258 had a Other on 12-Sep-19
# Patient 259 had a Simple Mastectomy on 14-Jun-19
# Patient 260 had a Lumpectomy on 10-Apr-18
# Patient 261 had a Modified Radical Mastectomy on 06-Dec-18
# Patient 262 had a Lumpectomy on 01-Nov-17
# Patient 263 had a Simple Mastectomy on 06-Dec-18
# Patient 264 had a Other on 04-Jun-17
# Patient 265 had a Other on 30-Jan-18
# Patient 266 had a Other on 06-Mar-19
# Patient 267 had a Other on 04-Feb-19
# Patient 268 had a Other on 07-Sep-18
# Patient 269 had a Simple Mastectomy on 04-Aug-18
# Patient 270 had a Lumpectomy on 27-Sep-18
# Patient 271 had a Other on 13-Aug-17
# Patient 272 had a Other on 02-Oct-19
# Patient 273 had a Simple Mastectomy on 24-Feb-19
# Patient 274 had a Lumpectomy on 21-Nov-17
# Patient 275 had a Modified Radical Mastectomy on 26-Nov-18
# Patient 276 had a Modified Radical Mastectomy on 20-Apr-18
# Patient 277 had a Modified Radical Mastectomy on 28-Sep-17
# Patient 278 had a Other on 16-Nov-18
# Patient 279 had a Simple Mastectomy on 22-Oct-19
# Patient 280 had a Lumpectomy on 01-Dec-17
# Patient 281 had a Lumpectomy on 26-May-17
# Patient 282 had a Simple Mastectomy on 17-Dec-17
# Patient 283 had a Other on 31-Jan-19
# Patient 284 had a Lumpectomy on 03-Sep-18
# Patient 285 had a Simple Mastectomy on 06-Mar-17
# Patient 286 had a Simple Mastectomy on 26-Nov-18
# Patient 287 had a Modified Radical Mastectomy on 24-Jun-19
# Patient 288 had a Other on 23-Aug-17
# Patient 289 had a Other on 16-Apr-18
# Patient 290 had a Modified Radical Mastectomy on 25-Jan-17
# Patient 291 had a Lumpectomy on 22-Mar-19
# Patient 292 had a Simple Mastectomy on 30-Apr-18
# Patient 293 had a Other on 03-Aug-19
# Patient 294 had a Modified Radical Mastectomy on 25-May-19
# Patient 295 had a Modified Radical Mastectomy on 23-Oct-18
# Patient 296 had a Simple Mastectomy on 10-May-18
# Patient 297 had a Simple Mastectomy on 07-Sep-18
# Patient 298 had a Modified Radical Mastectomy on 13-Aug-19
# Patient 299 had a Lumpectomy on 06-Dec-18
# Patient 300 had a Simple Mastectomy on 12-Sep-19
# Patient 301 had a Modified Radical Mastectomy on 25-Jan-19
# Patient 302 had a Lumpectomy on 17-Oct-18
# Patient 303 had a Simple Mastectomy on 26-May-18
# Patient 304 had a Modified Radical Mastectomy on 31-Dec-17
# Patient 305 had a Modified Radical Mastectomy on 17-Sep-18
# Patient 306 had a Other on 01-May-19
# Patient 307 had a Other on 11-Apr-19
# Patient 308 had a Simple Mastectomy on 12-Mar-19
# Patient 309 had a Modified Radical Mastectomy on 04-Jul-19
# Patient 310 had a Simple Mastectomy on 21-Mar-18
# Patient 311 had a Modified Radical Mastectomy on 06-Nov-18
# Patient 312 had a Other on 09-Feb-18
# Patient 313 had a Modified Radical Mastectomy on 24-Feb-19
# Patient 314 had a Simple Mastectomy on 07-Dec-17
# Patient 315 had a Other on 14-Feb-19
# Patient 316 had a Other on 05-Apr-19
# Patient 317 had a Simple Mastectomy on 15-Jun-18
# Patient 318 had a Modified Radical Mastectomy on 22-Sep-17
# Patient 319 had a Simple Mastectomy on 04-Aug-18
# Patient 320 had a Other on 27-Sep-18
# Patient 321 had a Simple Mastectomy on 16-May-17
# Patient 322 had a Modified Radical Mastectomy on 18-Sep-17
# Patient 323 had a Lumpectomy on 07-Mar-18
# Patient 324 had a Modified Radical Mastectomy on 19-Jul-18
# Patient 325 had a Other on 09-Jul-18
# Patient 326 had a Other on 12-Oct-19
# Patient 327 had a Other on 16-May-18
# Patient 328 had a Lumpectomy on 02-Oct-19
# Patient 329 had a Lumpectomy on 15-Jan-19
# Patient 330 had a Modified Radical Mastectomy on 25-Jul-18
# Patient 331 had a Simple Mastectomy on 26-Mar-19
# Patient 332 had a Lumpectomy on 26-Nov-18
# Patient 333 had a Modified Radical Mastectomy on 04-Feb-19
#      Patient_ID  Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0             0   42  FEMALE  0.952560   2.15000  0.007972 -0.048340
# 1             1   54  FEMALE  0.000000   1.38020 -0.498030 -0.507320
# 2             2   63  FEMALE -0.523030   1.76400 -0.370190  0.010815
# 3             3   78  FEMALE -0.876180   0.12943 -0.370380  0.132190
# 4             4   42  FEMALE  0.226110   1.74910 -0.543970 -0.390210
# ..          ...  ...     ...       ...       ...       ...       ...
# 329         329   59  FEMALE  0.024598   1.40050  0.024751  0.280320
# 330         330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870
# 331         331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860
# 332         332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820
# 333         333   66  FEMALE  0.286380   1.39980  0.318830  0.836050
#
#     Tumour_Stage                       Histology ER status PR status  \
# 0             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 1             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 2             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 3              I   Infiltrating Ductal Carcinoma  Positive  Positive
# 4             II   Infiltrating Ductal Carcinoma  Positive  Positive
# ..           ...                             ...       ...       ...
# 329           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 330            I   Infiltrating Ductal Carcinoma  Positive  Positive
# 331           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 332           II  Infiltrating Lobular Carcinoma  Positive  Positive
# 333           II   Infiltrating Ductal Carcinoma  Positive  Positive
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative                        Other       20-May-18
# 1      Negative                        Other       26-Apr-18
# 2      Negative                   Lumpectomy       24-Aug-18
# 3      Negative                        Other       16-Nov-18
# 4      Positive                   Lumpectomy       12-Dec-18
# ..          ...                          ...             ...
# 329    Positive                   Lumpectomy       15-Jan-19
# 330    Positive  Modified Radical Mastectomy       25-Jul-18
# 331    Negative            Simple Mastectomy       26-Mar-19
# 332    Negative                   Lumpectomy       26-Nov-18
# 333    Negative  Modified Radical Mastectomy       04-Feb-19
#
#     Date_of_Last_Visit Patient_Status
# 0            26-Aug-18          Alive
# 1            25-Jan-19           Dead
# 2            08-Apr-20          Alive
# 3            28-Jul-20          Alive
# 4            05-Jan-19          Alive
# ..                 ...            ...
# 329          27-Mar-20          Alive
# 330          23-Apr-19          Alive
# 331          11-Oct-19           Dead
# 332          05-Dec-18          Alive
# 333          10-Aug-19           Dead
#
# [334 rows x 16 columns]

# %%
#5. Groupby
survival_by_stage = pd.DataFrame(df.groupby(['Tumour_Stage', 'Patient_Status'])['Patient_ID'].count()).reset_index() #show how many breast cancer survivor there are that were originally diagnosed at each stage
stage_totals = survival_by_stage.groupby('Tumour_Stage')['Patient_ID'].transform('sum') #to make this more meaningful, add the percentages instead of the raw numbers
survival_by_stage['Percentage'] = (survival_by_stage['Patient_ID'] / stage_totals * 100).round(1)
survival_by_stage #we can see that as the stage increases there are slighly lower percentage of survivors
# Out:
#   Tumour_Stage Patient_Status  Patient_ID  Percentage
# 0            I          Alive          51        83.6
# 1            I           Dead          10        16.4
# 2           II          Alive         144        79.1
# 3           II           Dead          38        20.9
# 4          III          Alive          60        76.9
# 5          III           Dead          18        23.1
